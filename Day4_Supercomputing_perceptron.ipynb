# %%
# Step 1: Given Data

x = [75, 65, 80]      # Input marks
w = [4, 3, 5]         # Weights
b = -800              # Bias
eta = 0.01            # Learning rate
y = 1                 # Actual output (Pass)

# Step 2: Compute Net Input (z)

z = w[0]*x[0] + w[1]*x[1] + w[2]*x[2] + b

# Step 3: Apply Activation Function

if z >= 0:
    y_pred = 1
else:
    y_pred = 0

# Step 4: Calculate Error

error = y - y_pred

# Step 5: Update Weights

for i in range(len(w)):
    w[i] = w[i] + eta * error * x[i]

# Step 6: Update Bias

b = b + eta * error

# Output

print("Net input (z):", z)
print("Predicted output:", y_pred)
print("Error:", error)
print("Updated weights:", w)
print("Updated bias:", b)
# Out:
# Net input (z): 95
# Predicted output: 1
# Error: 0
# Updated weights: [4.0, 3.0, 5.0]
# Updated bias: -800.0
